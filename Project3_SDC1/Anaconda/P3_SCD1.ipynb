# %%
print("Hellow anaconda cloud")
# Out:
# Hellow anaconda cloud

# %%
import platform
print(platform.python_version())
# Out:
# 3.11.5

# %%
# pip install boto3 yml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: boto3 in ./.local/lib/python3.11/site-packages (1.41.0)
# Requirement already satisfied: yml in ./.local/lib/python3.11/site-packages (0.0.1)
# Requirement already satisfied: botocore<1.42.0,>=1.41.0 in ./.local/lib/python3.11/site-packages (from boto3) (1.41.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from boto3) (0.10.0)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in ./.local/lib/python3.11/site-packages (from boto3) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from botocore<1.42.0,>=1.41.0->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from botocore<1.42.0,>=1.41.0->boto3) (1.26.16)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.42.0,>=1.41.0->boto3) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
import yaml

# %%
with open('aws_credentials.yml', 'r') as file:
    aws_credentials = yaml.safe_load(file)
 
### Extract credentials from YAML
aws_access_key_id = aws_credentials['aws_access_key_id']
aws_secret_access_key = aws_credentials['aws_secret_access_key']
aws_region_name = aws_credentials['aws_region_name']
 
### Initialize a session using AWS credentials
session = boto3.Session(
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=aws_region_name)
 
### Update the below variables values with your details
file_name = 'customer_full_data.csv'
bucket_name = 'p3-scd1-data-bucket'
folder_name = 'data'
 
### Create an S3 client
s3_client = session.client('s3')
 
try: 
    ### Upload file in S3
    s3_client.upload_file( 
    Filename =file_name, 
    Bucket=bucket_name, 
    Key=folder_name + '/' + file_name
    )
    print(file_name + " is uploaded sucessfully")
 
except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# customer_full_data.csv is uploaded sucessfully

# %%
with open('aws_credentials.yml', 'r') as file:
    aws_credentials = yaml.safe_load(file)
 
### Extract credentials from YAML
aws_access_key_id = aws_credentials['aws_access_key_id']
aws_secret_access_key = aws_credentials['aws_secret_access_key']
aws_region_name = aws_credentials['aws_region_name']
 
### Initialize a session using AWS credentials
session = boto3.Session(
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=aws_region_name)
 
### Update the below variables values with your details
file_name = 'customer_change_data.csv'
bucket_name = 'p3-scd1-data-bucket'
folder_name = 'data'
 
### Create an S3 client
s3_client = session.client('s3')
 
try: 
    ### Upload file in S3
    s3_client.upload_file( 
    Filename =file_name, 
    Bucket=bucket_name, 
    Key=folder_name + '/' + file_name
    )
    print(file_name + " is uploaded sucessfully")
 
except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# customer_change_data.csv is uploaded sucessfully
